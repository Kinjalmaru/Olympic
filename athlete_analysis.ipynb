# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from IPython.display import display, HTML
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
def categorize_age(age):
    if (age<18):
        return 1
    elif (age<20):
        return 2
    elif (age<22):
        return 3
    elif (age<24):
        return 4
    elif (age<26):
        return 5
    elif (age<30):
        return 6
    elif (age<34):
        return 7
    elif (age<38):
        return 8
    elif (age<42):
        return 9
    elif (age<46):
        return 10
    else:
        return 11

def categorize_gender(gender):
    if gender == 'M':
        return 0
    else:
        return 1

# %%
num_bins = 10
label_names = list(range(1, num_bins + 1))

athlete_df = pd.read_csv('../data/athlete_data/athlete_events.csv')
summer_olympics_df = athlete_df.loc[athlete_df.Season == 'Summer']

noc_id_df = pd.read_csv('../data/athlete_data/NOC_Conversion.csv')

summer_olympics_df = pd.merge(summer_olympics_df, noc_id_df, on='NOC', suffixes=['','_y'])

# Filter out only events from 2016
olympics_2016_events = athlete_df.loc[athlete_df.Year == 2016]['Event'].unique()
summer_olympics_df = summer_olympics_df.loc[summer_olympics_df.Event.isin(olympics_2016_events)]

# Filter Events that have not been represented in at least 5 olympic games to eliminate newer events
summer_olympics_df['olympics_count'] = summer_olympics_df.groupby(['Event'])['Year'].transform('nunique')
summer_olympics_df = summer_olympics_df.loc[summer_olympics_df.olympics_count >= 5]

# Add columns
# add num competitors
summer_olympics_df['Competitor Count'] = summer_olympics_df.groupby(['Event', 'Year'])['ID'].transform('nunique')

# convert winning medal to whether athlete placed
summer_olympics_df['Placed'] = np.where(summer_olympics_df.Medal.notna(), 1, 0)

# add column for previously placed
previous_placed_df = summer_olympics_df.loc[summer_olympics_df.Placed == 1]
previous_placed_df = pd.merge(summer_olympics_df, previous_placed_df, on='ID', how='left', suffixes=('', '_y'))
previous_placed_df = previous_placed_df.loc[(previous_placed_df.Name_y.notna()) &
                                             (previous_placed_df.Year > previous_placed_df.Year_y)]
previous_placed_df['Previously Placed'] = 1

summer_olympics_df = pd.merge(summer_olympics_df, previous_placed_df, on=['ID', 'Year', 'Event'], how='left', suffixes=('', '_y'))

summer_olympics_df['Country Medals in Event'] = summer_olympics_df.groupby(['NOCID', 'Sport'])['Placed'].transform('sum')

summer_olympics_df = summer_olympics_df[['ID', 'Year', 'Age', 'Height', 'Weight', 'NOCID', 'Event', 'Previously Placed', 'Sex', 'Placed']]
summer_olympics_df = summer_olympics_df.drop_duplicates()
summer_olympics_df = summer_olympics_df.drop('ID', axis = 1)
summer_olympics_df['Age'] = summer_olympics_df['Age'].apply(categorize_age)
summer_olympics_df['Sex'] = summer_olympics_df['Sex'].apply(categorize_gender)
summer_olympics_df['Height'] = pd.cut(summer_olympics_df['Height'], bins = num_bins, labels = label_names, right=False, include_lowest=True)
summer_olympics_df['Weight'] = pd.cut(summer_olympics_df['Weight'], bins = num_bins, labels = label_names, right=False, include_lowest=True)
summer_olympics_df['Previously Placed'] = summer_olympics_df['Previously Placed'].fillna(0)

# %%
event_list = []

# %%
def calculate_variable_weight(Event):

    result_list = []

    summer_event_df = summer_olympics_df.loc[summer_olympics_df.Event == Event].copy()
    result_list.append(Event)

    event_df = summer_event_df.drop('Event', axis=1)
    event_df = event_df.drop('Year', axis=1)
    event_df = event_df.drop('Sex', axis=1)
    event_df.dropna(inplace=True)

    feature_names = event_df.columns

    X = event_df.iloc[:, :-1].values
    y = event_df.iloc[:, -1].values
    # labelencoder_X = LabelEncoder()
    # X[:,3] = labelencoder_X.fit_transform(X[:,3])



    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)


    clf = tree.DecisionTreeClassifier()
    clf = clf.fit(X_train, y_train)
    clf.score(X_test, y_test)

    rf = RandomForestClassifier(n_estimators=200)
    rf = rf.fit(X_train, y_train)

    result_list.append(rf.score(X_test, y_test))
    result_list.append(rf.feature_importances_[0])
    result_list.append(rf.feature_importances_[1])
    result_list.append(rf.feature_importances_[2])
    result_list.append(rf.feature_importances_[3])
    result_list.append(rf.feature_importances_[4])

    return result_list

# import multiprocessing
#
# PROCESSES = 2
# with multiprocessing.Pool(PROCESSES) as pool:
#     pool.map(calculate_variable_weight,summer_olympics_df['Event'].unique()[0:10])

# %%
event_list.clear()

for event in summer_olympics_df['Event'].unique():
    print(event)
    try:
        event_list.append(calculate_variable_weight(event))
    except:
        print('Error occurred. Skipping')

# i = 0
# event_list.clear()
#
# for event in summer_olympics_df['Event'].unique():
#     print(event)
#     calculateVariableWeight(event)
#
#     i += 1
#     if i > 10:
#         break
# Out:
# Basketball Men's Basketball
# Judo Men's Extra-Lightweight
# Boxing Men's Middleweight
# Swimming Women's 200 metres Freestyle
# Swimming Women's 4 x 200 metres Freestyle Relay
# Hockey Men's Hockey
# Judo Men's Middleweight
# Basketball Women's Basketball
# Wrestling Men's Heavyweight, Greco-Roman
# Archery Men's Individual
# Swimming Women's 200 metres Backstroke
# Boxing Men's Light-Heavyweight
# Triathlon Men's Olympic Distance
# Football Women's Football
# Rhythmic Gymnastics Women's Individual
# Athletics Women's 10,000 metres
# Badminton Men's Singles
# Football Men's Football
# Rhythmic Gymnastics Women's Group
# Wrestling Men's Light-Heavyweight, Freestyle
# Gymnastics Women's Individual All-Around
# Gymnastics Women's Team All-Around
# Gymnastics Women's Horse Vault
# Gymnastics Women's Uneven Bars
# Gymnastics Women's Balance Beam
# Athletics Men's Hammer Throw
# Volleyball Men's Volleyball
# Athletics Women's Shot Put
# Athletics Women's 400 metres
# Swimming Women's 100 metres Butterfly
# Swimming Women's 4 x 100 metres Medley Relay
# Athletics Men's 100 metres
# Athletics Men's 4 x 100 metres Relay
# Swimming Men's 50 metres Freestyle
# Swimming Men's 4 x 100 metres Freestyle Relay
# Athletics Men's Marathon
# Water Polo Men's Water Polo
# Athletics Men's High Jump
# Athletics Men's 50 kilometres Walk
# Hockey Women's Hockey
# Shooting Men's Air Rifle, 10 metres
# Shooting Men's Small-Bore Rifle, Three Positions, 50 metres
# Weightlifting Men's Middleweight
# Weightlifting Men's Light-Heavyweight
# Shooting Women's Sporting Pistol, 25 metres
# Cycling Men's Road Race, Individual
# Badminton Men's Doubles
# Athletics Men's 20 kilometres Walk
# Archery Women's Individual
# Archery Women's Team
# Weightlifting Women's Heavyweight
# Rowing Women's Double Sculls
# Rowing Women's Coxed Eights
# Rowing Women's Quadruple Sculls
# Athletics Women's Discus Throw
# Athletics Men's Triple Jump
# Shooting Men's Small-Bore Rifle, Prone, 50 metres
# Diving Men's Synchronized Platform
# Diving Men's Springboard
# Diving Men's Synchronized Springboard
# Swimming Women's 400 metres Freestyle
# Modern Pentathlon Men's Individual
# Swimming Men's 100 metres Freestyle
# Athletics Women's Javelin Throw
# Swimming Men's 200 metres Breaststroke
# Synchronized Swimming Women's Team
# Athletics Men's Decathlon
# Wrestling Men's Middleweight, Greco-Roman
# Swimming Women's 4 x 100 metres Freestyle Relay
# Handball Women's Handball
# Diving Men's Platform
# Athletics Men's Shot Put
# Fencing Men's Foil, Team
# Gymnastics Women's Floor Exercise
# Shooting Men's Skeet
# Shooting Women's Trap
# Judo Women's Middleweight
# Fencing Men's Sabre, Individual
# Volleyball Women's Volleyball
# Canoeing Men's Canadian Doubles, Slalom
# Fencing Men's Foil, Individual
# Swimming Women's 800 metres Freestyle
# Swimming Women's 100 metres Breaststroke
# Swimming Women's 200 metres Breaststroke
# Swimming Men's 100 metres Breaststroke
# Swimming Men's 4 x 100 metres Medley Relay
# Table Tennis Women's Singles
# Athletics Men's Long Jump
# Athletics Women's 4 x 400 metres Relay
# Fencing Women's Foil, Individual
# Athletics Men's 200 metres
# Tennis Women's Singles
# Tennis Women's Doubles
# Weightlifting Men's Featherweight
# Badminton Mixed Doubles
# Table Tennis Men's Singles
# Shooting Women's Air Rifle, 10 metres
# Shooting Women's Small-Bore Rifle, Three Positions, 50 metres
# Sailing Women's Windsurfer
# Athletics Men's Javelin Throw
# Modern Pentathlon Women's Individual
# Swimming Men's 200 metres Individual Medley
# Sailing Women's Two Person Dinghy
# Diving Women's Platform
# Diving Women's Synchronized Platform
# Boxing Men's Lightweight
# Cycling Women's Road Race, Individual
# Weightlifting Women's Middleweight
# Weightlifting Women's Flyweight
# Wrestling Men's Super-Heavyweight, Freestyle
# Sailing Mixed Multihull
# Swimming Women's 400 metres Individual Medley
# Swimming Women's 200 metres Individual Medley
# Swimming Women's 100 metres Backstroke
# Athletics Men's 110 metres Hurdles
# Weightlifting Women's Lightweight
# Gymnastics Men's Individual All-Around
# Gymnastics Men's Team All-Around
# Gymnastics Men's Floor Exercise
# Gymnastics Men's Parallel Bars
# Gymnastics Men's Horizontal Bar
# Gymnastics Men's Rings
# Gymnastics Men's Pommelled Horse
# Swimming Men's 200 metres Butterfly
# Badminton Women's Doubles
# Athletics Men's 400 metres
# Shooting Men's Rapid-Fire Pistol, 25 metres
# Athletics Women's 200 metres
# Athletics Women's 4 x 100 metres Relay
# Taekwondo Women's Heavyweight
# Canoeing Men's Canadian Doubles, 1,000 metres
# Swimming Men's 4 x 200 metres Freestyle Relay
# Cycling Men's Team Sprint
# Swimming Men's 100 metres Backstroke
# Swimming Women's 100 metres Freestyle
# Athletics Men's 400 metres Hurdles
# Beach Volleyball Women's Beach Volleyball
# Canoeing Men's Kayak Doubles, 1,000 metres
# Rowing Women's Coxless Pairs
# Handball Men's Handball
# Fencing Men's epee, Individual
# Fencing Men's epee, Team
# Swimming Men's 1,500 metres Freestyle
# Archery Men's Team
# Badminton Women's Singles
# Sailing Men's Two Person Dinghy
# Swimming Men's 200 metres Backstroke
# Canoeing Men's Kayak Singles, Slalom
# Weightlifting Women's Super-Heavyweight
# Trampolining Men's Individual
# Canoeing Women's Kayak Fours, 500 metres
# Athletics Women's Heptathlon
# Athletics Men's 1,500 metres
# Athletics Women's 100 metres Hurdles
# Shooting Men's Trap
# Rowing Women's Single Sculls
# Athletics Men's 800 metres
# Gymnastics Men's Horse Vault
# Cycling Men's Team Pursuit, 4,000 metres
# Rowing Men's Coxed Eights
# Canoeing Men's Canadian Singles, Slalom
# Cycling Men's Keirin
# Athletics Men's Pole Vault
# Diving Women's Springboard
# Diving Women's Synchronized Springboard
# Water Polo Women's Water Polo
# Canoeing Women's Kayak Singles, 500 metres
# Judo Men's Half-Lightweight
# Judo Women's Extra-Lightweight
# Athletics Women's 100 metres
# Cycling Women's Mountainbike, Cross-Country
# Cycling Women's Individual Time Trial
# Athletics Women's Pole Vault
# Athletics Women's High Jump
# Cycling Women's Sprint
# Synchronized Swimming Women's Duet
# Rowing Men's Coxless Fours
# Boxing Men's Bantamweight
# Athletics Women's Hammer Throw
# Athletics Women's Long Jump
# Athletics Men's Discus Throw
# Judo Men's Half-Middleweight
# Shooting Women's Air Pistol, 10 metres
# Swimming Women's 50 metres Freestyle
# Boxing Men's Welterweight
# Fencing Women's epee, Team
# Swimming Men's 400 metres Freestyle
# Judo Women's Half-Lightweight
# Taekwondo Women's Welterweight
# Trampolining Women's Individual
# Weightlifting Men's Bantamweight
# Wrestling Men's Welterweight, Freestyle
# Taekwondo Women's Featherweight
# Shooting Men's Double Trap
# Canoeing Women's Kayak Doubles, 500 metres
# Wrestling Men's Featherweight, Greco-Roman
# Boxing Men's Flyweight
# Boxing Men's Light-Welterweight
# Rowing Men's Double Sculls
# Rowing Men's Quadruple Sculls
# Athletics Women's Marathon
# Equestrianism Mixed Three-Day Event, Individual
# Athletics Women's Triple Jump
# Rowing Women's Lightweight Double Sculls
# Athletics Women's 400 metres Hurdles
# Rowing Men's Lightweight Coxless Fours
# Canoeing Men's Kayak Fours, 1,000 metres
# Equestrianism Mixed Jumping, Individual
# Equestrianism Mixed Jumping, Team
# Cycling Men's Mountainbike, Cross-Country
# Sailing Men's Windsurfer
# Swimming Men's 100 metres Butterfly
# Athletics Women's 20 kilometres Walk
# Boxing Men's Heavyweight
# Swimming Women's 200 metres Butterfly
# Swimming Men's 400 metres Individual Medley
# Judo Women's Lightweight
# Canoeing Men's Canadian Singles, 1,000 metres
# Judo Women's Half-Heavyweight
# Canoeing Women's Kayak Singles, Slalom
# Weightlifting Men's Lightweight
# Fencing Women's epee, Individual
# Judo Women's Half-Middleweight
# Wrestling Men's Featherweight, Freestyle
# Weightlifting Women's Featherweight
# Wrestling Men's Welterweight, Greco-Roman
# Swimming Men's 200 metres Freestyle
# Weightlifting Women's Light-Heavyweight
# Shooting Men's Free Pistol, 50 metres
# Judo Men's Half-Heavyweight
# Wrestling Men's Super-Heavyweight, Greco-Roman
# Canoeing Men's Kayak Singles, 1,000 metres
# Athletics Women's 1,500 metres
# Equestrianism Mixed Dressage, Individual
# Judo Men's Heavyweight
# Tennis Men's Doubles
# Taekwondo Men's Heavyweight
# Boxing Men's Light-Flyweight
# Athletics Men's 5,000 metres
# Athletics Men's 10,000 metres
# Wrestling Men's Light-Heavyweight, Greco-Roman
# Weightlifting Men's Middle-Heavyweight
# Shooting Men's Air Pistol, 10 metres
# Judo Men's Lightweight
# Sailing Men's One Person Dinghy
# Sailing Women's One Person Dinghy
# Triathlon Women's Olympic Distance
# Wrestling Men's Middleweight, Freestyle
# Rowing Men's Single Sculls
# Judo Women's Heavyweight
# Rowing Men's Lightweight Double Sculls
# Tennis Men's Singles
# Athletics Women's 5,000 metres
# Athletics Women's 800 metres
# Wrestling Men's Heavyweight, Freestyle
# Shooting Women's Skeet
# Cycling Men's Sprint
# Taekwondo Women's Flyweight
# Beach Volleyball Men's Beach Volleyball
# Weightlifting Men's Heavyweight
# Boxing Men's Super-Heavyweight
# Taekwondo Men's Flyweight
# Taekwondo Men's Welterweight
# Cycling Men's Individual Time Trial
# Rowing Men's Coxless Pairs
# Tennis Mixed Doubles
# Equestrianism Mixed Dressage, Team
# Athletics Men's 3,000 metres Steeplechase
# Taekwondo Men's Featherweight
# Equestrianism Mixed Three-Day Event, Team
# Athletics Men's 4 x 400 metres Relay
# Weightlifting Men's Super-Heavyweight

# %%
weight_variable_df = pd.DataFrame(event_list, columns=['Event', 'Fit', 'Age', 'Height', 'Weight', 'Country', 'Previously Placed'])
display(weight_variable_df)
weight_variable_df.to_csv('../data/results/variable_weight.csv', index=False)
# Out:
#                                                Event       Fit       Age  \
# 0                        Basketball Men's Basketball  0.872458  0.109819
# 1                       Judo Men's Extra-Lightweight  0.819444  0.163160
# 2                          Boxing Men's Middleweight  0.776471  0.251891
# 3              Swimming Women's 200 metres Freestyle  0.934579  0.231366
# 4    Swimming Women's 4 x 200 metres Freestyle Relay  0.863636  0.128944
# ..                                               ...       ...       ...
# 267        Athletics Men's 3,000 metres Steeplechase  0.905405  0.200492
# 268                    Taekwondo Men's Featherweight  0.789474  0.126564
# 269        Equestrianism Mixed Three-Day Event, Team  0.785714  0.256217
# 270             Athletics Men's 4 x 400 metres Relay  0.827684  0.154967
# 271            Weightlifting Men's Super-Heavyweight  0.775000  0.207842
#
#        Height    Weight   Country  Previously Placed
# 0    0.072301  0.048216  0.740779           0.028884
# 1    0.052844  0.050919  0.608196           0.124881
# 2    0.077406  0.011183  0.635506           0.024014
# 3    0.151308  0.085466  0.468306           0.063553
# 4    0.068577  0.046523  0.695167           0.060790
# ..        ...       ...       ...                ...
# 267  0.082794  0.046875  0.608709           0.061130
# 268  0.078420  0.023045  0.588683           0.183288
# 269  0.109741  0.049595  0.525667           0.058781
# 270  0.082529  0.038355  0.688959           0.035191
# 271  0.107567  0.192298  0.420136           0.072157
#
# [272 rows x 7 columns]

# %%
results_list = []

# %%
def predict_event_winner(Event):

    summer_event_df = summer_olympics_df.loc[summer_olympics_df.Event == Event].copy()

    event_df = summer_event_df.drop('Event', axis=1)
    event_df = event_df.drop('Sex', axis=1)
    event_df = event_df.loc[event_df.Year < 2016]
    event_df = event_df.drop('Year', axis = 1)
    event_df.dropna(inplace=True)

    feature_names = event_df.columns


    X = event_df.iloc[:, :-1].values
    y = event_df.iloc[:, -1].values
    labelencoder_X = LabelEncoder()
    X[:,3] = labelencoder_X.fit_transform(X[:,3])


    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)


    model = Sequential()

    model.add(Dense(50, activation='relu', input_dim=X_train.shape[1]))

    model.add(Dense(40, activation='relu'))
    model.add(Dense(40, activation='relu'))
    model.add(Dense(30, activation='relu'))
    model.add(Dense(30, activation='relu'))
    model.add(Dense(20, activation='relu'))


    model.add(Dense(y_train.shape[1],activation = 'softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


    X_train=np.asarray(X_train).astype(np.int)
    callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20)

    model.fit(X_train,
              y_train,
              epochs=10000,
              shuffle=True,
              callbacks=[callback],
              verbose=0)



    X_test = np.asarray(X_test).astype(np.int)


    summer_2016_df = summer_event_df.loc[summer_olympics_df.Year == 2016].dropna()
    for index, row in summer_2016_df.iterrows():
        competitor_array = np.asarray([[row['Age'], row['Height'], row['Weight'], row['NOCID'], row['Previously Placed']]]).astype(int)
        competitor = competitor_array.tolist()[0]
        competitor.append(Event)
        competitor.append(model.predict(competitor_array)[0][0])
        competitor.append(row['Placed'])
        results_list.append(competitor)

    # summer_2016_df['Predicted Placing'] = summer_2016_df.apply(lambda x: model.predict_classes(summer_event_df[['Age', 'Height', 'Weight', 'NOCID', 'Competitor Count', 'Previously Placed']]))

# %%
results_list.clear()

for event in summer_olympics_df['Event'].unique():
    print(event)
    predict_event_winner(event)
# Out:
# Basketball Men's Basketball
# Judo Men's Extra-Lightweight
# Boxing Men's Middleweight
# Swimming Women's 200 metres Freestyle
# Swimming Women's 4 x 200 metres Freestyle Relay
# Hockey Men's Hockey
# Judo Men's Middleweight
# Basketball Women's Basketball
# Wrestling Men's Heavyweight, Greco-Roman
# Archery Men's Individual
# Swimming Women's 200 metres Backstroke
# Boxing Men's Light-Heavyweight
# Triathlon Men's Olympic Distance
# Football Women's Football
# Rhythmic Gymnastics Women's Individual
# Athletics Women's 10,000 metres
# Badminton Men's Singles
# Football Men's Football
# Rhythmic Gymnastics Women's Group
# Wrestling Men's Light-Heavyweight, Freestyle
# Gymnastics Women's Individual All-Around
# Gymnastics Women's Team All-Around
# Gymnastics Women's Horse Vault
# Gymnastics Women's Uneven Bars
# Gymnastics Women's Balance Beam
# Athletics Men's Hammer Throw
# Volleyball Men's Volleyball
# Athletics Women's Shot Put
# Athletics Women's 400 metres
# Swimming Women's 100 metres Butterfly
# Swimming Women's 4 x 100 metres Medley Relay
# Athletics Men's 100 metres
# Athletics Men's 4 x 100 metres Relay
# Swimming Men's 50 metres Freestyle
# Swimming Men's 4 x 100 metres Freestyle Relay
# Athletics Men's Marathon
# Water Polo Men's Water Polo
# Athletics Men's High Jump
# Athletics Men's 50 kilometres Walk
# Hockey Women's Hockey
# Shooting Men's Air Rifle, 10 metres
# Shooting Men's Small-Bore Rifle, Three Positions, 50 metres
# Weightlifting Men's Middleweight
# Weightlifting Men's Light-Heavyweight
# Shooting Women's Sporting Pistol, 25 metres
# Cycling Men's Road Race, Individual
# Badminton Men's Doubles
# Athletics Men's 20 kilometres Walk
# Archery Women's Individual
# Archery Women's Team
# Weightlifting Women's Heavyweight
# Rowing Women's Double Sculls
# Rowing Women's Coxed Eights
# Rowing Women's Quadruple Sculls
# Athletics Women's Discus Throw
# Athletics Men's Triple Jump
# Shooting Men's Small-Bore Rifle, Prone, 50 metres
# Diving Men's Synchronized Platform
# Diving Men's Springboard
# Diving Men's Synchronized Springboard
# Swimming Women's 400 metres Freestyle
# Modern Pentathlon Men's Individual
# Swimming Men's 100 metres Freestyle
# Athletics Women's Javelin Throw
# Swimming Men's 200 metres Breaststroke
# Synchronized Swimming Women's Team
# Athletics Men's Decathlon
# Wrestling Men's Middleweight, Greco-Roman
# Swimming Women's 4 x 100 metres Freestyle Relay
# Handball Women's Handball
# Diving Men's Platform
# Athletics Men's Shot Put
# Fencing Men's Foil, Team
# Gymnastics Women's Floor Exercise
# Shooting Men's Skeet
# Shooting Women's Trap
# Judo Women's Middleweight
# Fencing Men's Sabre, Individual
# Volleyball Women's Volleyball
# Canoeing Men's Canadian Doubles, Slalom
# Fencing Men's Foil, Individual
# Swimming Women's 800 metres Freestyle
# Swimming Women's 100 metres Breaststroke
# Swimming Women's 200 metres Breaststroke
# Swimming Men's 100 metres Breaststroke
# Swimming Men's 4 x 100 metres Medley Relay
# Table Tennis Women's Singles
# Athletics Men's Long Jump
# Athletics Women's 4 x 400 metres Relay
# Fencing Women's Foil, Individual
# Athletics Men's 200 metres
# Tennis Women's Singles
# Tennis Women's Doubles
# Weightlifting Men's Featherweight
# Badminton Mixed Doubles
# Table Tennis Men's Singles
# Shooting Women's Air Rifle, 10 metres
# Shooting Women's Small-Bore Rifle, Three Positions, 50 metres
# Sailing Women's Windsurfer
# Athletics Men's Javelin Throw
# Modern Pentathlon Women's Individual
# Swimming Men's 200 metres Individual Medley
# Sailing Women's Two Person Dinghy
# Diving Women's Platform
# Diving Women's Synchronized Platform
# Boxing Men's Lightweight
# Cycling Women's Road Race, Individual
# Weightlifting Women's Middleweight
# Weightlifting Women's Flyweight
# Wrestling Men's Super-Heavyweight, Freestyle
# Sailing Mixed Multihull
# Swimming Women's 400 metres Individual Medley
# Swimming Women's 200 metres Individual Medley
# Swimming Women's 100 metres Backstroke
# Athletics Men's 110 metres Hurdles
# Weightlifting Women's Lightweight
# Gymnastics Men's Individual All-Around
# Gymnastics Men's Team All-Around
# Gymnastics Men's Floor Exercise
# Gymnastics Men's Parallel Bars
# Gymnastics Men's Horizontal Bar
# Gymnastics Men's Rings
# Gymnastics Men's Pommelled Horse
# Swimming Men's 200 metres Butterfly
# Badminton Women's Doubles
# Athletics Men's 400 metres
# Shooting Men's Rapid-Fire Pistol, 25 metres
# Athletics Women's 200 metres
# Athletics Women's 4 x 100 metres Relay
# Taekwondo Women's Heavyweight
# Canoeing Men's Canadian Doubles, 1,000 metres
# Swimming Men's 4 x 200 metres Freestyle Relay
# Cycling Men's Team Sprint
# Swimming Men's 100 metres Backstroke
# Swimming Women's 100 metres Freestyle
# Athletics Men's 400 metres Hurdles
# Beach Volleyball Women's Beach Volleyball
# Canoeing Men's Kayak Doubles, 1,000 metres
# Rowing Women's Coxless Pairs
# Handball Men's Handball
# Fencing Men's epee, Individual
# Fencing Men's epee, Team
# Swimming Men's 1,500 metres Freestyle
# Archery Men's Team
# Badminton Women's Singles
# Sailing Men's Two Person Dinghy
# Swimming Men's 200 metres Backstroke
# Canoeing Men's Kayak Singles, Slalom
# Weightlifting Women's Super-Heavyweight
# Trampolining Men's Individual
# Canoeing Women's Kayak Fours, 500 metres
# Athletics Women's Heptathlon
# Athletics Men's 1,500 metres
# Athletics Women's 100 metres Hurdles
# Shooting Men's Trap
# Rowing Women's Single Sculls
# Athletics Men's 800 metres
# Gymnastics Men's Horse Vault
# Cycling Men's Team Pursuit, 4,000 metres
# Rowing Men's Coxed Eights
# Canoeing Men's Canadian Singles, Slalom
# Cycling Men's Keirin
# Athletics Men's Pole Vault
# Diving Women's Springboard
# Diving Women's Synchronized Springboard
# Water Polo Women's Water Polo
# Canoeing Women's Kayak Singles, 500 metres
# Judo Men's Half-Lightweight
# Judo Women's Extra-Lightweight
# Athletics Women's 100 metres
# Cycling Women's Mountainbike, Cross-Country
# Cycling Women's Individual Time Trial
# Athletics Women's Pole Vault
# Athletics Women's High Jump
# Cycling Women's Sprint
# Synchronized Swimming Women's Duet
# Rowing Men's Coxless Fours
# Boxing Men's Bantamweight
# Athletics Women's Hammer Throw
# Athletics Women's Long Jump
# Athletics Men's Discus Throw
# Judo Men's Half-Middleweight
# Shooting Women's Air Pistol, 10 metres
# Swimming Women's 50 metres Freestyle
# Boxing Men's Welterweight
# Fencing Women's epee, Team
# Swimming Men's 400 metres Freestyle
# Judo Women's Half-Lightweight
# Taekwondo Women's Welterweight
# Trampolining Women's Individual
# Weightlifting Men's Bantamweight
# Wrestling Men's Welterweight, Freestyle
# Taekwondo Women's Featherweight
# Shooting Men's Double Trap
# Canoeing Women's Kayak Doubles, 500 metres
# Wrestling Men's Featherweight, Greco-Roman
# Boxing Men's Flyweight
# Boxing Men's Light-Welterweight
# Rowing Men's Double Sculls
# Rowing Men's Quadruple Sculls
# Athletics Women's Marathon
# Equestrianism Mixed Three-Day Event, Individual
# Athletics Women's Triple Jump
# Rowing Women's Lightweight Double Sculls
# Athletics Women's 400 metres Hurdles
# Rowing Men's Lightweight Coxless Fours
# Canoeing Men's Kayak Fours, 1,000 metres
# Equestrianism Mixed Jumping, Individual
# Equestrianism Mixed Jumping, Team
# Cycling Men's Mountainbike, Cross-Country
# Sailing Men's Windsurfer
# Swimming Men's 100 metres Butterfly
# Athletics Women's 20 kilometres Walk
# Boxing Men's Heavyweight
# Swimming Women's 200 metres Butterfly
# Swimming Men's 400 metres Individual Medley
# Judo Women's Lightweight
# Canoeing Men's Canadian Singles, 1,000 metres
# Judo Women's Half-Heavyweight
# Canoeing Women's Kayak Singles, Slalom
# Weightlifting Men's Lightweight
# Fencing Women's epee, Individual
# Judo Women's Half-Middleweight
# Wrestling Men's Featherweight, Freestyle
# Weightlifting Women's Featherweight
# Wrestling Men's Welterweight, Greco-Roman
# Swimming Men's 200 metres Freestyle
# Weightlifting Women's Light-Heavyweight
# Shooting Men's Free Pistol, 50 metres
# Judo Men's Half-Heavyweight
# Wrestling Men's Super-Heavyweight, Greco-Roman
# Canoeing Men's Kayak Singles, 1,000 metres
# Athletics Women's 1,500 metres
# Equestrianism Mixed Dressage, Individual
# Judo Men's Heavyweight
# Tennis Men's Doubles
# Taekwondo Men's Heavyweight
# Boxing Men's Light-Flyweight
# Athletics Men's 5,000 metres
# Athletics Men's 10,000 metres
# Wrestling Men's Light-Heavyweight, Greco-Roman
# Weightlifting Men's Middle-Heavyweight
# Shooting Men's Air Pistol, 10 metres
# Judo Men's Lightweight
# Sailing Men's One Person Dinghy
# Sailing Women's One Person Dinghy
# Triathlon Women's Olympic Distance
# Wrestling Men's Middleweight, Freestyle
# Rowing Men's Single Sculls
# Judo Women's Heavyweight
# Rowing Men's Lightweight Double Sculls
# Tennis Men's Singles
# Athletics Women's 5,000 metres
# Athletics Women's 800 metres
# Wrestling Men's Heavyweight, Freestyle
# Shooting Women's Skeet
# Cycling Men's Sprint
# Taekwondo Women's Flyweight
# Beach Volleyball Men's Beach Volleyball
# Weightlifting Men's Heavyweight
# Boxing Men's Super-Heavyweight
# Taekwondo Men's Flyweight
# Taekwondo Men's Welterweight
# Cycling Men's Individual Time Trial
# Rowing Men's Coxless Pairs
# Tennis Mixed Doubles
# Equestrianism Mixed Dressage, Team
# Athletics Men's 3,000 metres Steeplechase
# Taekwondo Men's Featherweight
# Equestrianism Mixed Three-Day Event, Team
# Athletics Men's 4 x 400 metres Relay
# Weightlifting Men's Super-Heavyweight

# %%
print(results_list)

results_df = pd.DataFrame(results_list, columns=['Age', 'Height', 'Weight', 'NCOID', 'Previously Placed', 'Event', 'Prediction', 'Placed'])
results_df.to_csv('../data/results/placement_predictions.csv', index=False)

results_df['pred_rank'] = results_df.groupby('Event').Prediction.rank('max', ascending=False)
results_df.loc[(results_df.pred_rank < 3) & (results_df.Placed == 1)]
# Out:
# [[4, 8, 4, 73, 0, "Basketball Men's Basketball", 0.98874, 0], [4, 7, 4, 73, 0, "Basketball Men's Basketball", 0.9912674, 0], [6, 7, 5, 73, 0, "Basketball Men's Basketball", 0.9922375, 0], [5, 10, 5, 73, 0, "Basketball Men's Basketball", 0.97871953, 0], [5, 7, 4, 73, 0, "Basketball Men's Basketball", 0.9932359, 0], [4, 9, 4, 73, 0, "Basketball Men's Basketball", 0.9856302, 0], [6, 9, 5, 73, 0, "Basketball Men's Basketball", 0.9875207, 0], [4, 8, 4, 73, 0, "Basketball Men's Basketball", 0.98874, 0], [3, 6, 3, 73, 0, "Basketball Men's Basketball", 0.9943151, 0], [6, 8, 5, 73, 0, "Basketball Men's Basketball", 0.99009526, 0], [3, 10, 4, 73, 0, "Basketball Men's Basketball", 0.97732985, 0], [3, 8, 5, 73, 0, "Basketball Men's Basketball", 0.9817172, 0], [6, 8, 5, 5, 0, "Basketball Men's Basketball", 0.9879903, 0], [6, 7, 4, 5, 0, "Basketball Men's Basketball", 0.9381754, 0], [8, 8, 5, 5, 0, "Basketball Men's Basketball", 0.99515826, 0], [6, 7, 4, 5, 0, "Basketball Men's Basketball", 0.9381754, 0], [7, 8, 4, 5, 0, "Basketball Men's Basketball", 0.9852031, 0], [5, 9, 5, 5, 0, "Basketball Men's Basketball", 0.99826115, 0], [6, 7, 4, 5, 0, "Basketball Men's Basketball", 0.9381754, 0], [7, 8, 5, 5, 0, "Basketball Men's Basketball", 0.99158466, 0], [5, 9, 5, 5, 0, "Basketball Men's Basketball", 0.99826115, 0], [8, 6, 3, 5, 0, "Basketball Men's Basketball", 0.98824894, 0], [8, 8, 5, 5, 0, "Basketball Men's Basketball", 0.99515826, 0], [6, 9, 5, 5, 0, "Basketball Men's Basketball", 0.99737155, 0], [4, 8, 4, 2, 0, "Basketball Men's Basketball", 0.71823287, 1], [8, 7, 4, 2, 1, "Basketball Men's Basketball", 0.8379342, 1], [6, 8, 5, 2, 1, "Basketball Men's Basketball", 0.7442025, 1], [7, 7, 4, 2, 1, "Basketball Men's Basketball", 0.8134177, 1], [8, 9, 5, 2, 1, "Basketball Men's Basketball", 0.69398683, 1], [4, 9, 5, 2, 0, "Basketball Men's Basketball", 0.7241975, 1], [6, 7, 4, 2, 1, "Basketball Men's Basketball", 0.7567753, 1], [5, 9, 4, 2, 0, "Basketball Men's Basketball", 0.6842078, 1], [8, 7, 4, 2, 1, "Basketball Men's Basketball", 0.8379342, 1], [8, 8, 5, 2, 1, "Basketball Men's Basketball", 0.7266346, 1], [7, 7, 3, 2, 1, "Basketball Men's Basketball", 0.64755833, 1], [5, 7, 4, 2, 1, "Basketball Men's Basketball", 0.64516264, 1], [5, 9, 5, 47, 0, "Basketball Men's Basketball", 0.9216993, 0], [4, 8, 4, 47, 0, "Basketball Men's Basketball", 0.94320494, 0], [5, 6, 4, 47, 0, "Basketball Men's Basketball", 0.97185147, 0], [3, 8, 5, 47, 0, "Basketball Men's Basketball", 0.91298676, 0], [7, 7, 4, 47, 1, "Basketball Men's Basketball", 0.94234264, 0], [5, 9, 5, 47, 0, "Basketball Men's Basketball", 0.9216993, 0], [4, 7, 4, 47, 0, "Basketball Men's Basketball", 0.9525124, 0], [9, 8, 4, 47, 1, "Basketball Men's Basketball", 0.9689237, 0], [6, 7, 4, 47, 0, "Basketball Men's Basketball", 0.9743697, 0], [7, 8, 5, 47, 0, "Basketball Men's Basketball", 0.962537, 0], [8, 8, 5, 47, 1, "Basketball Men's Basketball", 0.9311377, 0], [8, 8, 5, 47, 1, "Basketball Men's Basketball", 0.9311377, 0], [7, 8, 5, 11, 1, "Basketball Men's Basketball", 0.72387666, 1], [5, 8, 5, 11, 0, "Basketball Men's Basketball", 0.9590415, 1], [6, 8, 4, 11, 0, "Basketball Men's Basketball", 0.99213797, 1], [5, 9, 6, 11, 0, "Basketball Men's Basketball", 0.9622382, 1], [6, 8, 4, 11, 0, "Basketball Men's Basketball", 0.99213797, 1], [6, 8, 5, 11, 1, "Basketball Men's Basketball", 0.6424572, 1], [6, 8, 4, 11, 0, "Basketball Men's Basketball", 0.99213797, 1], [6, 8, 5, 11, 0, "Basketball Men's Basketball", 0.9741563, 1], [5, 7, 4, 11, 0, "Basketball Men's Basketball", 0.8983702, 1], [6, 9, 6, 11, 0, "Basketball Men's Basketball", 0.9733184, 1], [7, 6, 4, 11, 0, "Basketball Men's Basketball", 0.98852134, 1], [6, 8, 4, 11, 0, "Basketball Men's Basketball", 0.99213797, 1], [7, 7, 4, 28, 0, "Basketball Men's Basketball", 0.97319376, 0], [6, 9, 5, 28, 0, "Basketball Men's Basketball", 0.9533327, 0], [7, 8, 5, 28, 0, "Basketball Men's Basketball", 0.9653035, 0], [8, 7, 4, 28, 0, "Basketball Men ...
#        Age  Height  Weight  NCOID  Previously Placed  \
# 190      3       6       3     18                  0
# 1517     6       6       4      4                  1
# 1594     3       2       1     73                  0
# 3175     6       6       3      3                  1
# 3633     7       5       3      2                  0
# 3895     6       5       3     11                  1
# 3943     4       5       3     11                  0
# 4151     3       5       2     73                  0
# 5817     7       5       2      5                  0
# 6127     4       4       3    168                  0
# 6831     2       6       3    115                  0
# 6931     3       7       4      5                  0
# 7669     3       6       3    110                  0
# 7673     7       7       4      5                  0
# 7675     9       6       3      5                  0
# 8256     7       3       2    168                  0
# 8828     8       7       3      2                  0
# 8991     6       4       2     20                  0
# 9459     5       5       3      3                  0
# 9597     5       5       3     22                  0
# 10667    6       5       3      8                  0
# 10696    5       5       3      4                  0
# 10723    5       4       2    164                  1
# 11727    7       7       4      1                  0
# 11796    3       4       2      4                  0
# 11902    4       6       2    114                  0
# 11964    3       8       4      3                  0
# 12100    6       6       3      2                  1
#
#                                                    Event  Prediction  Placed  \
# 190                            Boxing Men's Middleweight    0.999824       1
# 1517        Wrestling Men's Light-Heavyweight, Freestyle    0.999600       1
# 1594                  Gymnastics Women's Team All-Around    0.999917       1
# 3175   Shooting Men's Small-Bore Rifle, Three Positio...    0.999981       1
# 3633                   Weightlifting Women's Heavyweight    0.999915       1
# 3895                  Diving Men's Synchronized Platform    0.999999       1
# 3943               Diving Men's Synchronized Springboard    0.939703       1
# 4151                  Synchronized Swimming Women's Team    0.986732       1
# 5817                          Sailing Women's Windsurfer    1.000000       1
# 6127                  Weightlifting Women's Middleweight    0.999970       1
# 6831                 Swimming Men's 200 metres Butterfly    1.000000       1
# 6931         Shooting Men's Rapid-Fire Pistol, 25 metres    1.000000       1
# 7669                      Fencing Men's epee, Individual    0.999603       1
# 7673                            Fencing Men's epee, Team    0.979918       1
# 7675                            Fencing Men's epee, Team    0.982266       1
# 8256                        Gymnastics Men's Horse Vault    0.999934       1
# 8828                         Athletics Women's High Jump    1.000000       1
# 8991                           Boxing Men's Bantamweight    0.999997       1
# 9459             Wrestling Men's Welterweight, Freestyle    0.999952       1
# 9597                     Boxing Men's Light-Welterweight    0.990680       1
# 10667                     Judo Women's Half-Middleweight    0.997613       1
# 10696           Wrestling Men's Featherweight, Freestyle    0.999969       1
# 10723                Weightlifting Women's Featherweight    0.999990       1
# 11727             Wrestling Men's Heavyweight, Freestyle    1.000000       1
# 11796                        Taekwondo Women's Flyweight    0.999969       1
# 11902                          Taekwondo Men's Flyweight    0.999605       1
# 11964                         Rowing Men's Coxless Pairs    0.995481       1
# 12100                      Taekwondo Men's Featherweight    0.999331       1
#
#        pred_rank
# 190          2.0
# 1517         1.0
# 1594         2.0
# 3175         1.0
# 3633         1.0
# 3895         1.0
# 3943         2.0
# 4151         2.0
# 5817         1.0
# 6127         1.0
# 6831         2.0
# 6931         1.0
# 7669         2.0
# 7673         2.0
# 7675         1.0
# 8256         2.0
# 8828         1.0
# 8991         2.0
# 9459         1.0
# 9597         1.0
# 10667        1.0
# 10696        2.0
# 10723        2.0
# 11727        1.0
# 11796        2.0
# 11902        2.0
# 11964        1.0
# 12100        2.0
